# %% [markdown]
# # Setting up Project

# %%
# log in with the email account associated with your GCP.
import os 
curDir = !pwd
if curDir[0] == '/content':
  from google.colab import auth
  auth.authenticate_user()

# %%
# !gcloud projects list
# Out:
# PROJECT_ID                    NAME                          PROJECT_NUMBER
# billingprj                    BillingPrj                    346241010245
# bq-part-clust                 MLA-01-RSDW                   591958418924
# dd-sales-funnel               dd-sales-funnel               135191404955
# doordash-287907               Doordash                      945652970732
# fin-trading                   Financial-Trading             563366445397
# ipl-stream                    ipl-stream                    459986636125
# masterproject-277322          MasterProject                 799744540190
# mlacademy-prj                 mlacademy-prj                 593200915250
# qwiklabs-gcp-01-1bda0c438033  qwiklabs-gcp-01-1bda0c438033  859711784674
# rsa-app-services              RSA-App-Services              571647258835
# rsa-dev-10                    MLA-03-RSA-DEV                777754064427
# rsa-mla-prod                  rsa-mla-prod                  84569519344
# tpc-ds-01                     tpc-ds-01                     1077692525573

# %%
project_id = "qwiklabs-gcp-01-1bda0c438033"
project_id
# Out:
# 'qwiklabs-gcp-01-1bda0c438033'

# %%
os.environ['PROJECT'] = project_id
# !gcloud config set project {project_id}
# Out:
# Updated property [core/project].

# %%
os.environ['PROJECT_ID'] = project_id
# !echo $PROJECT_ID
# Out:
# qwiklabs-gcp-01-1bda0c438033

# %% [markdown]
# # Setup

# %% [markdown]
# ## Set Default Region

# %%
# !gcloud config set compute/region us-central1
# Out:
# Updated property [compute/region].

# %% [markdown]
# ## Create bucket

# %%
# !gsutil mb -c regional -l us-central1 gs://$PROJECT_ID
# Out:
# Creating gs://qwiklabs-gcp-01-1bda0c438033/...
# ServiceException: 409 A Cloud Storage bucket named 'qwiklabs-gcp-01-1bda0c438033' already exists. Try another name. Bucket names must be globally unique across all Google Cloud projects, including those outside of your organization.

# %% [markdown]
# # BQ Fundamentals

# %% [markdown]
# ## Create Dataset

# %% [markdown]
# ### Simple *creation*

# %%
# !echo "project_id = {project_id}" > ~/.bigqueryrc

# %%
# !bq mk --location=US \
      --default_table_expiration 3600 \
      DS01
# Out:
# Dataset 'qwiklabs-gcp-01-1bda0c438033:DS01' successfully created.

# %% [markdown]
# ### Conditional *creation*

# %%
# %%bash
# bq_safe_mk() {
#     dataset=$1
#     exists=$(bq ls --datasets | grep -w $dataset)
#     if [ -n "$exists" ]; then
#         echo "Not creating $dataset since it already exists"
#     else
#         echo "Creating $dataset"
#         bq mk $dataset
#     fi
# }
#
# bq_safe_mk DS01
#
# bq_safe_mk DS02
# Out:
# Not creating DS01 since it already exists
# Creating DS02
# Dataset 'qwiklabs-gcp-01-1bda0c438033:DS02' successfully created.

# %% [markdown]
# ## Create Tables

# %% [markdown]
# ### Simple Table Creation

# %%
# !bq mk --table \
    --expiration 3600 \
    --description "Simple Table" \
     --label persistence:volatile \
     DS01.employees employee_id:INTEGER,employee_name:STRING,age:FLOAT
# Out:
# Table 'qwiklabs-gcp-01-1bda0c438033:DS01.employees' successfully created.

# %% [markdown]
# ### Table creation with schema file

# %%
# %%writefile sales_schema.json
# [
#   {
#     "description": "quarter",
#     "mode": "REQUIRED",
#     "name": "qtr",
#     "type": "STRING"
#   },
#   {
#     "description": "sales representative",
#     "mode": "NULLABLE",
#     "name": "rep",
#     "type": "STRING"
#   },
#   {
#     "description": "total sales",
#     "mode": "NULLABLE",
#     "name": "sales",
#     "type": "FLOAT"
#   }
# ]
# Out:
# Overwriting sales_schema.json

# %%
# !bq mk --table \
    --expiration 3600 \
    --description "Sales data" \
     --label persistence:volatile \
     DS01.quarterly_sales_data sales_schema.json
# Out:
# Table 'qwiklabs-gcp-01-1bda0c438033:DS01.quarterly_sales_data' successfully created.

# %% [markdown]
# ### Table with nested fields

# %% [markdown]
# Example schema
# The following example shows sample nested and repeated data. This table contains information about people. It consists of the following fields:
#
# - id
# - first_name
# - last_name
# - dob (date of birth)
# - addresses (a nested and repeated field)
#  - addresses.status (current or previous)
#  - addresses.address
#  - addresses.city
#  - addresses.state
#  - addresses.zip
#  - addresses.numberOfYears (years at the address

# %% [markdown]
# #### Defining Nested & Repeated Schema

# %%
# %%writefile customer_data_schema.json
# [
#     {
#         "name": "cust_id",
#         "type": "STRING",
#         "mode": "NULLABLE"
#     },
#     {
#         "name": "first_name",
#         "type": "STRING",
#         "mode": "NULLABLE"
#     },
#     {
#         "name": "last_name",
#         "type": "STRING",
#         "mode": "NULLABLE"
#     },
#     {
#         "name": "dob",
#         "type": "DATE",
#         "mode": "NULLABLE"
#     },
#     {
#         "name": "addresses",
#         "type": "RECORD",
#         "mode": "REPEATED",
#         "fields": [
#             {
#                 "name": "status",
#                 "type": "STRING",
#                 "mode": "NULLABLE"
#             },
#             {
#                 "name": "address",
#                 "type": "STRING",
#                 "mode": "NULLABLE"
#             },
#             {
#                 "name": "city",
#                 "type": "STRING",
#                 "mode": "NULLABLE"
#             },
#             {
#                 "name": "state",
#                 "type": "STRING",
#                 "mode": "NULLABLE"
#             },
#             {
#                 "name": "zip",
#                 "type": "STRING",
#                 "mode": "NULLABLE"
#             },
#             {
#                 "name": "numberOfYears",
#                 "type": "STRING",
#                 "mode": "NULLABLE"
#             }
#         ]
#     }
# ]
# Out:
# Overwriting customer_data_schema.json

# %% [markdown]
# #### Creating Table with Nested & Repeated Fields

# %%
# !bq mk --table \
    --expiration 3600 \
    --description "Customer data" \
     --label persistence:volatile \
     DS01.customer_data customer_data_schema.json
# Out:
# Table 'qwiklabs-gcp-01-1bda0c438033:DS01.customer_data' successfully created.

# %% [markdown]
# #### Creating Customer data json

# %%
# %%writefile customer_data_data.json
# {"cust_id":"1","first_name":"John","last_name":"Doe","dob":"1968-01-22","addresses":[{"status":"current","address":"123 First Avenue","city":"Seattle","state":"WA","zip":"11111","numberOfYears":"1"},{"status":"previous","address":"456 Main Street","city":"Portland","state":"OR","zip":"22222","numberOfYears":"5"}]}
# {"cust_id":"2","first_name":"Jane","last_name":"Doe","dob":"1980-10-16","addresses":[{"status":"current","address":"789 Any Avenue","city":"New York","state":"NY","zip":"33333","numberOfYears":"2"},{"status":"previous","address":"321 Main Street","city":"Hoboken","state":"NJ","zip":"44444","numberOfYears":"3"}]}
# Out:
# Overwriting customer_data_data.json

# %% [markdown]
# #### Insert data into nested table

# %%
# !bq insert DS01.customer_data customer_data_data.json
# Out:
# BigQuery error in insert operation: Table 859711784674:DS01.customer_data is re-
# created.

# %% [markdown]
# ## Load Data to Tables

# %% [markdown]
# ### Load data to new table (table creation)

# %% [markdown]
# #### Load Data from a public dataset

# %%
# !bq load \
    --source_format=CSV \
    --autodetect \
    DS02.iowa_sales_from_cloud_shell \
    "gs://ven-gc-shared-01/datasets/iowa-liqour-sales/iowa-sales.csv"
# Out:
# Waiting on bqjob_r7e16f8fbe46d222d_0000017b0f60439c_1 ... (2s) Current status: DONE

# %% [markdown]
# #### Schema of the new table

# %%
# %%bigquery --project {project_id}
# SELECT table_name, column_name,ordinal_position,is_nullable,data_type
#  FROM
#    DS02.INFORMATION_SCHEMA.COLUMNS
#  WHERE
#    table_name="iowa_sales_from_cloud_shell"
# Out:
#                      table_name              column_name  ...  is_nullable data_type
# 0   iowa_sales_from_cloud_shell  invoice_and_item_number  ...          YES    STRING
# 1   iowa_sales_from_cloud_shell                     date  ...          YES      DATE
# 2   iowa_sales_from_cloud_shell             store_number  ...          YES     INT64
# 3   iowa_sales_from_cloud_shell               store_name  ...          YES    STRING
# 4   iowa_sales_from_cloud_shell                  address  ...          YES    STRING
# 5   iowa_sales_from_cloud_shell                     city  ...          YES    STRING
# 6   iowa_sales_from_cloud_shell                 zip_code  ...          YES    STRING
# 7   iowa_sales_from_cloud_shell           store_location  ...          YES    STRING
# 8   iowa_sales_from_cloud_shell            county_number  ...          YES     INT64
# 9   iowa_sales_from_cloud_shell                   county  ...          YES    STRING
# 10  iowa_sales_from_cloud_shell                 category  ...          YES     INT64
# 11  iowa_sales_from_cloud_shell            category_name  ...          YES    STRING
# 12  iowa_sales_from_cloud_shell            vendor_number  ...          YES     INT64
# 13  iowa_sales_from_cloud_shell              vendor_name  ...          YES    STRING
# 14  iowa_sales_from_cloud_shell              item_number  ...          YES     INT64
# 15  iowa_sales_from_cloud_shell         item_description  ...          YES    STRING
# 16  iowa_sales_from_cloud_shell                     pack  ...          YES     INT64
# 17  iowa_sales_from_cloud_shell         bottle_volume_ml  ...          YES     INT64
# 18  iowa_sales_from_cloud_shell        state_bottle_cost  ...          YES   FLOAT64
# 19  iowa_sales_from_cloud_shell      state_bottle_retail  ...          YES   FLOAT64
# 20  iowa_sales_from_cloud_shell             bottles_sold  ...          YES     INT64
# 21  iowa_sales_from_cloud_shell             sale_dollars  ...          YES   FLOAT64
# 22  iowa_sales_from_cloud_shell       volume_sold_liters  ...          YES   FLOAT64
# 23  iowa_sales_from_cloud_shell      volume_sold_gallons  ...          YES   FLOAT64
#
# [24 rows x 5 columns]

# %% [markdown]
# #### Load data to plain tables

# %%
# !bq load \
    --source_format=CSV \
    --autodetect \
    DS02.iowa_sales_plain \
    "gs://ven-gc-shared-01/datasets/iowa-liqour-sales/iowa-sales.csv"
# Out:
# Waiting on bqjob_r719eb81baf407bc7_0000017b0f605cbd_1 ... (3s) Current status: DONE

# %% [markdown]
# ### Partionted Tables

# %% [markdown]
# #### Load data to partionined tables

# %%
# !bq load \
    --source_format=CSV \
    --time_partitioning_type=DAY \
    --time_partitioning_field date \
    --autodetect \
    DS02.iowa_sales_partitioned \
    "gs://ven-gc-shared-01/datasets/iowa-liqour-sales/iowa-sales.csv"
# Out:
# Waiting on bqjob_r36d04c2a2e35a369_0000017b0f6072b8_1 ... (34s) Current status: DONE

# %% [markdown]
# #### Querrying Partioned tables

# %%
# %%bigquery --project {project_id}
# SELECT * FROM `DS02.iowa_sales_plain`where date BETWEEN '2012-01-01' AND '2012-01-31';
# Out:
#    invoice_and_item_number        date  ...  volume_sold_liters volume_sold_gallons
# 0             S03651300006  2012-01-19  ...                9.00                2.38
# 1             S03385800026  2012-01-03  ...                9.00                2.38
# 2             S03694500034  2012-01-23  ...                9.00                2.38
# 3             S03471300017  2012-01-09  ...                9.00                2.38
# 4             S03688300027  2012-01-23  ...                9.00                2.38
# 5             S03414400004  2012-01-04  ...                9.00                2.38
# 6             S03479000094  2012-01-09  ...                9.00                2.38
# 7             S03456700095  2012-01-05  ...               60.00               15.85
# 8             S03773800029  2012-01-26  ...                1.88                0.50
# 9             S03446100027  2012-01-05  ...                9.00                2.38
# 10            S03598300032  2012-01-17  ...               60.00               15.85
# 11            S03752800002  2012-01-25  ...                0.40                0.11
# 12            S03642200087  2012-01-18  ...                5.00                1.32
# 13            S03824600004  2012-01-31  ...                9.00                2.38
# 14            S03688200064  2012-01-23  ...                9.00                2.38
# 15            S03444500003  2012-01-05  ...                9.00                2.38
# 16            S03393400011  2012-01-03  ...                9.00                2.38
# 17            S03406300097  2012-01-03  ...                1.88                0.50
# 18            S03490900002  2012-01-10  ...                9.00                2.38
# 19            S03839800044  2012-01-31  ...                9.00                2.38
# 20            S03780300132  2012-01-26  ...               84.00               22.19
# 21            S03666200029  2012-01-19  ...                9.00                2.38
# 22            S03620000037  2012-01-17  ...                9.00                2.38
# 23            S03452100060  2012-01-05  ...                9.00                2.38
# 24            S03760300025  2012-01-26  ...               27.00                7.13
# 25            S03614900009  2012-01-17  ...                9.00                2.38
# 26            S03385300048  2012-01-03  ...                9.00                2.38
# 27            S03771600047  2012-01-26  ...                9.00                2.38
# 28            S03813700022  2012-01-30  ...              120.00               31.70
# 29            S03583600030  2012-01-16  ...              132.00               34.87
# 30            S03637000047  2012-01-18  ...              396.00              104.61
# 31            S03418900042  2012-01-04  ...                7.00                1.85
# 32            S03612100032  2012-01-17  ...                9.00                2.38
# 33            S03412400385  2012-01-04  ...                9.00                2.38
# 34            S03522700054  2012-01-11  ...                9.00                2.38
# 35            S03776200017  2012-01-26  ...                9.00                2.38
# 36            S03394500003  2012-01-03  ...                9.00                2.38
# 37            S03511600004  2012-01-10  ...                9.00                2.38
# 38            S03844700022  2012-01-31  ...                9.00                2.38
# 39            S03461400015  2012-01-09  ...                9.00                2.38
# 40            S03427200021  2012-01-04  ...                9.00                2.38
# 41            S03445600018  2012-01-05  ...                9.00                2.38
# 42            S03846200060  2012-01-31  ...                5.00                1.32
# 43            S03417000008  2012-01-04  ...               48.00               12.68
# 44            S03614500005  2012-01-17  ...                7.00                1.85
# 45            S03627200002  2012-01-18  ...                9.00                2.38
# 46            S03544400059  2012-01-12  ...               99.00               26.15
# 47            S03661600032  2012-01-19  ...               48.00               12.68
# 48            S03593600097  2012-01-16  ...               60.00               15.85
# 49            S03816900136  2012-01-30  ...               96.00               25.36
# 50            S03656600051  2012-01-19  ...                8.00                2.11
# 51            S03444300045  2012-01-05  ...                8.00                2.11
# 52            S03778900024  2012-01-26  ...                1.88                0.50
# 53            S03580100008  2012-01-16  ...                9.00                2.38
# 54            S03725500001  2012-01-24  ...              157.50               41.61
# 55            S03702100010  2012-01-23  ...               48.00               12.68
# 56            S03674200017  2012-01-23  ...               84.00               22.19
# 57            S03780300139  2012-01-26  ...               60.00               15.85
# 58            S03458900021  2012-01-09  ...                9.00                2.38
#
# [59 rows x 24 columns]

# %%
# %%bigquery --project {project_id}
# SELECT * FROM `DS02.iowa_sales_partitioned` where date BETWEEN '2012-01-01' AND '2012-01-31';
# Out:
#    invoice_and_item_number        date  ...  volume_sold_liters volume_sold_gallons
# 0             S03522700054  2012-01-11  ...                9.00                2.38
# 1             S03544400059  2012-01-12  ...               99.00               26.15
# 2             S03816900136  2012-01-30  ...               96.00               25.36
# 3             S03813700022  2012-01-30  ...              120.00               31.70
# 4             S03702100010  2012-01-23  ...               48.00               12.68
# 5             S03674200017  2012-01-23  ...               84.00               22.19
# 6             S03688200064  2012-01-23  ...                9.00                2.38
# 7             S03694500034  2012-01-23  ...                9.00                2.38
# 8             S03688300027  2012-01-23  ...                9.00                2.38
# 9             S03824600004  2012-01-31  ...                9.00                2.38
# 10            S03844700022  2012-01-31  ...                9.00                2.38
# 11            S03839800044  2012-01-31  ...                9.00                2.38
# 12            S03846200060  2012-01-31  ...                5.00                1.32
# 13            S03406300097  2012-01-03  ...                1.88                0.50
# 14            S03385300048  2012-01-03  ...                9.00                2.38
# 15            S03393400011  2012-01-03  ...                9.00                2.38
# 16            S03385800026  2012-01-03  ...                9.00                2.38
# 17            S03394500003  2012-01-03  ...                9.00                2.38
# 18            S03725500001  2012-01-24  ...              157.50               41.61
# 19            S03760300025  2012-01-26  ...               27.00                7.13
# 20            S03778900024  2012-01-26  ...                1.88                0.50
# 21            S03780300139  2012-01-26  ...               60.00               15.85
# 22            S03780300132  2012-01-26  ...               84.00               22.19
# 23            S03776200017  2012-01-26  ...                9.00                2.38
# 24            S03771600047  2012-01-26  ...                9.00                2.38
# 25            S03773800029  2012-01-26  ...                1.88                0.50
# 26            S03418900042  2012-01-04  ...                7.00                1.85
# 27            S03412400385  2012-01-04  ...                9.00                2.38
# 28            S03414400004  2012-01-04  ...                9.00                2.38
# 29            S03427200021  2012-01-04  ...                9.00                2.38
# 30            S03417000008  2012-01-04  ...               48.00               12.68
# 31            S03752800002  2012-01-25  ...                0.40                0.11
# 32            S03580100008  2012-01-16  ...                9.00                2.38
# 33            S03583600030  2012-01-16  ...              132.00               34.87
# 34            S03593600097  2012-01-16  ...               60.00               15.85
# 35            S03614500005  2012-01-17  ...                7.00                1.85
# 36            S03598300032  2012-01-17  ...               60.00               15.85
# 37            S03614900009  2012-01-17  ...                9.00                2.38
# 38            S03612100032  2012-01-17  ...                9.00                2.38
# 39            S03620000037  2012-01-17  ...                9.00                2.38
# 40            S03458900021  2012-01-09  ...                9.00                2.38
# 41            S03479000094  2012-01-09  ...                9.00                2.38
# 42            S03471300017  2012-01-09  ...                9.00                2.38
# 43            S03461400015  2012-01-09  ...                9.00                2.38
# 44            S03444300045  2012-01-05  ...                8.00                2.11
# 45            S03452100060  2012-01-05  ...                9.00                2.38
# 46            S03444500003  2012-01-05  ...                9.00                2.38
# 47            S03445600018  2012-01-05  ...                9.00                2.38
# 48            S03446100027  2012-01-05  ...                9.00                2.38
# 49            S03456700095  2012-01-05  ...               60.00               15.85
# 50            S03490900002  2012-01-10  ...                9.00                2.38
# 51            S03511600004  2012-01-10  ...                9.00                2.38
# 52            S03651300006  2012-01-19  ...                9.00                2.38
# 53            S03666200029  2012-01-19  ...                9.00                2.38
# 54            S03661600032  2012-01-19  ...               48.00               12.68
# 55            S03656600051  2012-01-19  ...                8.00                2.11
# 56            S03627200002  2012-01-18  ...                9.00                2.38
# 57            S03642200087  2012-01-18  ...                5.00                1.32
# 58            S03637000047  2012-01-18  ...              396.00              104.61
#
# [59 rows x 24 columns]

# %% [markdown]
# ### Clustering Tables

# %% [markdown]
# #### Load data into clustering columns

# %%
# !bq load \
    --source_format=CSV \
    --time_partitioning_type=DAY \
    --time_partitioning_field date \
    --clustering_fields vendor_name,item_description \
    --autodetect \
    DS02.iowa_sales_clustered \
    "gs://ven-gc-shared-01/datasets/iowa-liqour-sales/iowa-sales.csv "
# Out:
# Waiting on bqjob_r3eb119cfeca155cd_0000017b0f610d16_1 ... (34s) Current status: DONE

# %% [markdown]
# #### Querying Clustered Tables

# %%
# %%bigquery --project {project_id}
# SELECT vendor_name,item_description,sum(sale_dollars) as sales
# FROM `DS02.iowa_sales_partitioned`
# where date BETWEEN '2012-01-01' AND '2012-01-31'
# group by vendor_name,item_description;
# Out:
#                          vendor_name  ...    sales
# 0                    Jim Beam Brands  ...   113.40
# 1          Phillips Beverage Company  ...    85.56
# 2                     Luxco-St Louis  ...    79.92
# 3                     Luxco-St Louis  ...   285.30
# 4                    Jim Beam Brands  ...  2248.08
# 5                  Sazerac Co., Inc.  ...  4380.48
# 6                     Luxco-St Louis  ...   144.36
# 7                    Jim Beam Brands  ...   226.80
# 8   Pernod Ricard USA/Austin Nichols  ...  1804.78
# 9                      Castle Brands  ...   153.00
# 10         Phillips Beverage Company  ...    92.76
# 11                    Luxco-St Louis  ...   110.72
# 12      REMY COINTREAU USA         .  ...   162.00
# 13                    Luxco-St Louis  ...   180.00
# 14                   Jim Beam Brands  ...   110.16
# 15                    Luxco-St Louis  ...   427.80
# 16                   Jim Beam Brands  ...   199.20
# 17                   Jim Beam Brands  ...   113.40
# 18                   Jim Beam Brands  ...   190.54
# 19             Sazerac North America  ...    76.44
# 20                   Jim Beam Brands  ...    22.95
# 21                   Jim Beam Brands  ...   113.40
# 22                   Jim Beam Brands  ...   113.40
# 23                    Luxco-St Louis  ...   142.80
# 24                   Jim Beam Brands  ...   121.80
# 25                    Luxco-St Louis  ...    93.84
# 26  Mississippi River Distilling Co.  ...  5724.60
# 27          Park Street Imports-Voli  ...   230.28
# 28  Pernod Ricard USA/Austin Nichols  ...  1143.00
# 29                    Luxco-St Louis  ...    25.00
# 30                    Luxco-St Louis  ...   635.52
# 31                   Jim Beam Brands  ...   925.68
# 32                    Luxco-St Louis  ...    93.84
# 33                Heaven Hill Brands  ...    22.00
# 34             Sazerac North America  ...   171.00
# 35                 Sazerac Co., Inc.  ...    22.50
# 36                   Jim Beam Brands  ...  1247.40
# 37                    Luxco-St Louis  ...    78.96
# 38                   Jim Beam Brands  ...   113.40
# 39           Moet Hennessy USA, Inc.  ...   179.76
#
# [40 rows x 3 columns]

# %%
# %%bigquery --project {project_id}
# SELECT vendor_name,item_description,sum(sale_dollars) as sales
# FROM `DS02.iowa_sales_clustered`
# where date BETWEEN '2012-01-01' AND '2012-01-31'
# group by vendor_name,item_description;
# Out:
#                          vendor_name  ...    sales
# 0                    Jim Beam Brands  ...   226.80
# 1   Pernod Ricard USA/Austin Nichols  ...  1804.78
# 2                    Jim Beam Brands  ...   113.40
# 3                     Luxco-St Louis  ...   635.52
# 4                     Luxco-St Louis  ...   180.00
# 5                     Luxco-St Louis  ...   142.80
# 6                     Luxco-St Louis  ...    78.96
# 7                    Jim Beam Brands  ...   113.40
# 8                    Jim Beam Brands  ...   113.40
# 9                    Jim Beam Brands  ...    22.95
# 10  Mississippi River Distilling Co.  ...  5724.60
# 11           Moet Hennessy USA, Inc.  ...   179.76
# 12                   Jim Beam Brands  ...   110.16
# 13      REMY COINTREAU USA         .  ...   162.00
# 14                    Luxco-St Louis  ...   285.30
# 15                    Luxco-St Louis  ...   427.80
# 16                    Luxco-St Louis  ...   110.72
# 17                   Jim Beam Brands  ...   199.20
# 18                   Jim Beam Brands  ...   113.40
# 19                   Jim Beam Brands  ...   190.54
# 20             Sazerac North America  ...    76.44
# 21                    Luxco-St Louis  ...    93.84
# 22                   Jim Beam Brands  ...   121.80
# 23                 Sazerac Co., Inc.  ...  4380.48
# 24                   Jim Beam Brands  ...  2248.08
# 25                    Luxco-St Louis  ...   144.36
# 26                 Sazerac Co., Inc.  ...    22.50
# 27             Sazerac North America  ...   171.00
# 28                Heaven Hill Brands  ...    22.00
# 29                    Luxco-St Louis  ...    25.00
# 30                    Luxco-St Louis  ...    93.84
# 31  Pernod Ricard USA/Austin Nichols  ...  1143.00
# 32                   Jim Beam Brands  ...   925.68
# 33                   Jim Beam Brands  ...   113.40
# 34         Phillips Beverage Company  ...    85.56
# 35                    Luxco-St Louis  ...    79.92
# 36                     Castle Brands  ...   153.00
# 37         Phillips Beverage Company  ...    92.76
# 38          Park Street Imports-Voli  ...   230.28
# 39                   Jim Beam Brands  ...  1247.40
#
# [40 rows x 3 columns]
